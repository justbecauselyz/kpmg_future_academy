# %% [markdown]
# # 금융위원회 주식배당정보

# %%
from dotenv import load_dotenv
import os
from pathlib import Path

# .env 파일에 예: PUBLIC_DATA_KEY=your_key

env_path = Path('.') / '.env'
load_dotenv(dotenv_path=env_path, override=True)

PUBLIC_DATA_KEY = os.getenv("PUBLIC_DATA_KEY")
if PUBLIC_DATA_KEY is None:
    raise RuntimeError("PUBLIC_DATA_KEY가 .env에 없습니다.")
# PUBLIC_DATA_KEY

# %%
import requests

url = 'http://apis.data.go.kr/1160100/service/GetStocDiviInfoService/getDiviInfo'
params = {
    'serviceKey' : PUBLIC_DATA_KEY,
    'pageNo' : '10',
    'numOfRows' : '100',
    # 'resultType' : 'xml',
    'resultType' : 'json',
    'basDt' : '',
    # 'crno' : '1101110057012',
    'stckIssuCmpyNm' : '' 
    }

response = requests.get(url, params=params)
# print(response.content)  # xml일 경우
print(response.json())  # json일 경우
# Out:
# {'response': {'body': {'items': {'item': [{'basDt': '20251120', 'crno': '1101110012776', 'isinCd': 'KR7000230003', 'stckIssuCmpyNm': '일동홀딩스', 'isinCdNm': '일동홀딩스', 'scrsItmsKcd': '0101', 'scrsItmsKcdNm': '보통주', 'stckParPrc': '1000', 'trsnmDptyDcd': '01', 'trsnmDptyDcdNm': '한국예탁결제원', 'stckStacMd': '12', 'dvdnBasDt': '19950331', 'cashDvdnPayDt': '19950711', 'stckHndvDt': '19950711', 'stckDvdnRcd': '03', 'stckDvdnRcdNm': '동시배당', 'stckGenrDvdnAmt': '0', 'stckGrdnDvdnAmt': '0', 'stckGenrCashDvdnRt': '1', 'stckGenrDvdnRt': '3', 'cashGrdnDvdnRt': '0', 'stckGrdnDvdnRt': '0'}, {'basDt': '20251120', 'crno': '1101110012776', 'isinCd': 'KR7000230003', 'stckIssuCmpyNm': '일동홀딩스', 'isinCdNm': '일동홀딩스', 'scrsItmsKcd': '0101', 'scrsItmsKcdNm': '보통주', 'stckParPrc': '1000', 'trsnmDptyDcd': '01', 'trsnmDptyDcdNm': '한국예탁결제원', 'stckStacMd': '12', 'dvdnBasDt': '19960331', 'cashDvdnPayDt': '19960626', 'stckHndvDt': '19960626', 'stckDvdnRcd': '03', 'stckDvdnRcdNm': '동시배당', 'stckGenrDvdnAmt': '0', 'stckGrdnDvdnAmt': '0', 'stckGenrCashDvdnRt': '1', 'stckGenrDvdnRt': '3', 'cashGrdnDvdnRt': '0', 'stckGrdnDvdnRt': '0'}, {'basDt': '20251120', 'crno': '1101110012776', 'isinCd': 'KR7000230003', 'stckIssuCmpyNm': '일동홀딩스', 'isinCdNm': '일동홀딩스', 'scrsItmsKcd': '0101', 'scrsItmsKcdNm': '보통주', 'stckParPrc': '1000', 'trsnmDptyDcd': '01', 'trsnmDptyDcdNm': '한국예탁결제원', 'stckStacMd': '12', 'dvdnBasDt': '19970331', 'cashDvdnPayDt': '19970627', 'stckHndvDt': '19970627', 'stckDvdnRcd': '03', 'stckDvdnRcdNm': '동시배당', 'stckGenrDvdnAmt': '0', 'stckGrdnDvdnAmt': '0', 'stckGenrCashDvdnRt': '2', 'stckGenrDvdnRt': '3', 'cashGrdnDvdnRt': '0', 'stckGrdnDvdnRt': '0'}, {'basDt': '20251120', 'crno': '1101110012776', 'isinCd': 'KR7000230003', 'stckIssuCmpyNm': '일동홀딩스', 'isinCdNm': '일동홀딩스', 'scrsItmsKcd': '0101', 'scrsItmsKcdNm': '보통주', 'stckParPrc': '1000', 'trsnmDptyDcd': '01', 'trsnmDptyDcdNm': '한국예탁결제원', 'stckStacMd': '12', 'dvdnBasDt': '19980331', 'cashDvdnPayDt': '19980629', 'stckHndvDt': '19980629', 'stckDvdnRcd': '03', 'stckDvdnRcdNm': '동시배당', 'stckGenrDvdnAmt': '0', 'stckGrdnDvdnAmt': '0', 'stckGenrCashDvdnRt': '1', 'stckGenrDvdnRt': '3', 'cashGrdnDvdnRt': '0', 'stckGrdnDvdnRt': '0'}, {'basDt': '20251120', 'crno': '1101110012776', 'isinCd': 'KR7000230003', 'stckIssuCmpyNm': '일동홀딩스', 'isinCdNm': '일동홀딩스', 'scrsItmsKcd': '0101', 'scrsItmsKcdNm': '보통주', 'stckParPrc': '1000', 'trsnmDptyDcd': '01', 'trsnmDptyDcdNm': '한국예탁결제원', 'stckStacMd': '12', 'dvdnBasDt': '19990331', 'cashDvdnPayDt': '', 'stckHndvDt': '', 'stckDvdnRcd': '04', 'stckDvdnRcdNm': '무배당', 'stckGenrDvdnAmt': '0', 'stckGrdnDvdnAmt': '0', 'stckGenrCashDvdnRt': '0', 'stckGenrDvdnRt': '0', 'cashGrdnDvdnRt': '0', 'stckGrdnDvdnRt': '0'}, {'basDt': '20251120', 'crno': '1101110012776', 'isinCd': 'KR7000230003', 'stckIssuCmpyNm': '일동홀딩스', 'isinCdNm': '일동홀딩스', 'scrsItmsKcd': '0101', 'scrsItmsKcdNm': '보통주', 'stckParPrc': '1000', 'trsnmDptyDcd': '01', 'trsnmDptyDcdNm': '한국예탁결제원', 'stckStacMd': '12', 'dvdnBasDt': '20000331', 'cashDvdnPayDt': '', 'stckHndvDt': '', 'stckDvdnRcd': '04', 'stckDvdnRcdNm': '무배당', 'stckGenrDvdnAmt': '0', 'stckGrdnDvdnAmt': '0', 'stckGenrCashDvdnRt': '0', 'stckGenrDvdnRt': '0', 'cashGrdnDvdnRt': '0', 'stckGrdnDvdnRt': '0'}, {'basDt': '20251120', 'crno': '1101110012776', 'isinCd': 'KR7000230003', 'stckIssuCmpyNm': '일동홀딩스', 'isinCdNm': '일동홀딩스', 'scrsItmsKcd': '0101', 'scrsItmsKcdNm': '보통주', 'stckParPrc': '1000', 'trsnmDptyDcd': '01', 'trsnmDptyDcdNm': '한국예탁결제원', 'stckStacMd': '12', 'dvdnBasDt': '20010331', 'cashDvdnPayDt': '', 'stckHndvDt': '', 'stckDvdnRcd': '02', 'stckDvdnRcdNm': '현금배당', 'stckGenrDvdnAmt': '0', 'stckGrdnDvdnAmt': '0', 'stckGenrCashDvdnRt': '0', 'stckGenrDvdnRt': '0', 'cashGrdnDvdnRt': '0', 'stckGrdnDvdnRt': '0'}, {'basDt': '20251120', 'crno': '1101110012776', 'isinCd': 'KR7000230003', 'stckIssuCmpyNm': '일동홀딩스', 'isinCdNm': '일동홀딩스', 'scrsItmsKcd': '0101', 'scrsItmsKcdNm': '보통주', 'stckParPrc': '1000', 'trsnmDptyDcd': '01', 'trsnmDptyDcdNm': '한국예탁결제원', 'stckStacMd': '12', 'dvdnBasDt': '20020331' ...

# %%
import pandas as pd

df = pd.DataFrame(response.json()['response']['body']['items']['item'])
df.head()
# Out:
#       basDt           crno        isinCd stckIssuCmpyNm isinCdNm scrsItmsKcd  \
# 0  20251120  1101110012776  KR7000230003          일동홀딩스    일동홀딩스        0101
# 1  20251120  1101110012776  KR7000230003          일동홀딩스    일동홀딩스        0101
# 2  20251120  1101110012776  KR7000230003          일동홀딩스    일동홀딩스        0101
# 3  20251120  1101110012776  KR7000230003          일동홀딩스    일동홀딩스        0101
# 4  20251120  1101110012776  KR7000230003          일동홀딩스    일동홀딩스        0101
#
#   scrsItmsKcdNm stckParPrc trsnmDptyDcd trsnmDptyDcdNm  ... cashDvdnPayDt  \
# 0           보통주       1000           01        한국예탁결제원  ...      19950711
# 1           보통주       1000           01        한국예탁결제원  ...      19960626
# 2           보통주       1000           01        한국예탁결제원  ...      19970627
# 3           보통주       1000           01        한국예탁결제원  ...      19980629
# 4           보통주       1000           01        한국예탁결제원  ...
#
#   stckHndvDt stckDvdnRcd stckDvdnRcdNm stckGenrDvdnAmt stckGrdnDvdnAmt  \
# 0   19950711          03          동시배당               0               0
# 1   19960626          03          동시배당               0               0
# 2   19970627          03          동시배당               0               0
# 3   19980629          03          동시배당               0               0
# 4                     04           무배당               0               0
#
#   stckGenrCashDvdnRt stckGenrDvdnRt cashGrdnDvdnRt stckGrdnDvdnRt
# 0                  1              3              0              0
# 1                  1              3              0              0
# 2                  2              3              0              0
# 3                  1              3              0              0
# 4                  0              0              0              0
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (100, 22)
