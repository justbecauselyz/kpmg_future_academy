# %% [markdown]
# # 파이썬 테스트

# %%
print("헬로 파이썬")
# Out:
# 헬로 파이썬

# %%
# 파이썬 버전 확인
# %%python --version
# Out:
# Python 3.12.11

# %%
input()
# Out:
# 안녕
# '안녕'

# %%
input("숫자를 입력하세요. >")
# Out:
# 숫자를 입력하세요. >1
# '1'

# %%
num = input("숫자를 입력하세요. >")
# Out:
# 숫자를 입력하세요. >5

# %%
num
# Out:
# '5'

# %%
num = input("숫자를 입력하세요. >")
# Out:
# 숫자를 입력하세요. >7

# %%
num
# Out:
# '7'

# %%
# int: 정수형
type(7)
# Out:
# int

# %%
# str: 문자형
type(num)
# Out:
# str

# %%
# 형변환(casting): 문자 -> 숫자(정수)
num = int(num)
print(num)
print(type(num))
# Out:
# 7
# <class 'int'>

# %%
# 단축키
# 코드 셀 -> 문자 셀 : ctrl + m -> ctrl + m
# 문자 셀 -> 코드 셀 : ctrl + m -> ctrl + y

# %% [markdown]
# # 파이썬의 기본 자료형
# - 기본 자료형 : 한번에 하나의 값만 변수에 저장
# - 숫자 : int, float
# - 문자 : str
# - 불(bool) : bool

# %%
True # <- 1
# Out:
# True

# %%
False # <- 0
# Out:
# False

# %%
# 실수
type(0.5)
# Out:
# float

# %%
mun_f =20.0
type(mun_f)
# Out:
# float

# %%
type(True)
# Out:
# bool
