# %% [markdown]
# # PYTHON PROGRAMMING FUNDAMENTALS
# # TUPLES AND SETS

# %%
# 리스트
[]

# %%
# 딕서너리
{"키", "값"}

# %%
# 튜플
()
# Out:
# ()

# %% [markdown]
# # TUPLES
#
# - Immutable Python objects.
# - 튜플은 순서가 있습니다.
# - 튜플은 괄호 ( ) 를 사용합니다.

# %%
my_tuple = (1, 2, 3)
my_tuple
# Out:
# (1, 2, 3)

# %%
# 괄호 쳐도 안친거랑 결론이 같음 (괄호 쳐져서 나옴)
my_tuple = 1, 2, 3
my_tuple
# Out:
# (1, 2, 3)

# %%
one_ele = 1
type(one_ele)
# Out:
# int

# %%
one_ele = 1,
one_ele
type(one_ele)
# Out:
# tuple

# %%
my_tuple
# Out:
# (1, 2, 3)

# %%
# Immutable 하기 때문
my_tuple[1] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3444954880.py in <cell line: 0>()
# ----> 1 my_tuple[1] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # SETS
# - 셋에 들어있는 데이터는 순서가 없습니다.
# - 셋에는 동일한 값이 저장되지 않습니다. 우리가 배웠던 집합과 같습니다.
# - 셋은 중괄호 { } 로 정의합니다.

# %%
data = set()
data
# Out:
# set()

# %%
set_data = {1,2,3,4,5,6,7,8,8,9,77,6,3,2,}
set_data
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9, 77}

# %%
# 리스트 -> 집합으로 캐스팅(형변환)
list_data = [1,2,3,4,5,6,7,8,8,9,77,6,3,2,]
list_data
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 8, 9, 77, 6, 3, 2]

# %%
set(list_data)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9, 77}

# %%
# 튜플 -> 집합으로 캐스팅(형변환)
tuple_data = (1,2,3,4,5,6,7,8,8,9,77,6,3,2,)
tuple_data
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 8, 9, 77, 6, 3, 2)

# %%
set(tuple_data)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9, 77}

# %%
set_data = set(tuple_data)
